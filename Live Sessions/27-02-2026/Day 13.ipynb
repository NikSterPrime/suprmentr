# %%
'''
what is KNN ?
it is a:
*classifier
*regression

It is:
*lazy learner
*instance based learning
*non parametric(no assumptions about data distributions)

"Scenario: You move to a new apartment and want to know if the area is good or bad ?"
'''
