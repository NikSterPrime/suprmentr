# %%
'''
                    Outlook
               /       |       \
            Sunny   Overcast   Rain
              |        |        |
          Humidity    Play     Wind
          /     \               /   \
       High   Normal        Strong Weak
        |        |            |      |
      Don't     Play        Don't    Play
       Play                  Play
'''
